# %%
import json 
import time
import tweepy
import numpy as np

# %%
consumer_key = "E4KWCdr3WaSkZvtdGi0fTorKA"
consumer_secret =  "BjOPzr6HARhsWpDpt6GL7qQtlAVjNnq4jCxTurTyCZ5oaz5j2x"
access_token =  "616460006-yu97qY1Hadeqv6imnfmZwweJvOLSTYdCEz3jvO5J"
access_token_secret = "V9gdaJOA4agtU3dq7ziuxsbSMeoTLrmAcaCEchJK7TDkY"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
id_collector = []
tweet_collector = []
max_id = None
interval = 2

for i in range(2):
    mentions = api.mentions_timeline (since_id=max_id)
    
    for mention in mentions: 
        tweet_collector.append(mention['text'].lower())
        id_collector.append(mention['id'])
        max_id = max(id_collector)
        print(mention)
    time.sleep(interval)
# Out:
# {'created_at': 'Sun Jun 14 05:39:11 +0000 2020', 'id': 1272040871236530179, 'id_str': '1272040871236530179', 'text': '@Pratham_2210 sf vs. sj', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Pratham_2210', 'name': 'Pratham', 'id': 616460006, 'id_str': '616460006', 'indices': [0, 13]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': 616460006, 'in_reply_to_user_id_str': '616460006', 'in_reply_to_screen_name': 'Pratham_2210', 'user': {'id': 616460006, 'id_str': '616460006', 'name': 'Pratham', 'screen_name': 'Pratham_2210', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 3, 'friends_count': 9, 'listed_count': 0, 'created_at': 'Sat Jun 23 20:49:22 +0000 2012', 'favourites_count': 0, 'utc_offset': None, 'time_zone': Non
# ...

# %%
first_splitter = 'pratham_2210'
second_splitter = 'vs.'

for tweet in tweet_collector:  
    temp = tweet.split(first_splitter)
    temp2 = temp[1].split(second_splitter)
    print(temp2)
# Out:
# [' sf ', ' sj']
# [' american airlines ', ' delta']
# [' clorox ', ' lysol']

# %%
tweet_collector = []

# "Real Person" Filters
min_tweets = 5
max_tweets = 10000
max_followers = 2500
max_following = 2500
lang = "en"

# Target Search Term
target_terms = ("sf", "sj", "american airlines",
                "delta", "clorox", "lysol")

for x in range(20):
    
    public_tweets = api.search(
            '#sf', count=200, result_type="recent")
    
    for tweet in public_tweets['statuses']:
        
        if(tweet['user']["followers_count"] < max_followers
                and tweet['user']["statuses_count"] > min_tweets
                and tweet['user']["statuses_count"] < max_tweets
                and tweet['user']["friends_count"] < max_following
                and tweet["lang"] == lang):
            tweet_collector.append(tweet['text'])
            print(tweet['text'])
        #print(json.dumps(tweet, sort_keys=True, indent=4, separators=(',', ': ')))
# Out:
# RT @UCLFightsFakes: For a new perspective on the issue of #SF medicines during COVID-19, register to join @FIP_org @FIPYPG @UCLFightsFakes…
# RT @UCLFightsFakes: For a new perspective on the issue of #SF medicines during COVID-19, register to join @FIP_org @FIPYPG @UCLFightsFakes…
# In 3 months, I learned how to work w/health insurance to cover #autism assessment &amp; group therapy, found amazing ne… https://t.co/Y99REbtRDS
# RT @UCSFChildrens: GREAT NEWS: Our hospitals in #SF and #Oakland again have ranked among the nation's top hospitals for kids, according to…
# Anyone in the #mission #SF hear that explosion?..
# spare a thought for SF @geoffzzzzzz  this saturday who has not missed an EPL game since Cherries were promoted. Wil… https://t.co/VZgVZYcKEf
# RT @UCSFChildrens: GREAT NEWS: Our hospitals in #SF and #Oakland again have ranked among the nation's top hospitals for kids, according to…
# ...

# %%
len(tweet_collector)
# Out:
# 640
